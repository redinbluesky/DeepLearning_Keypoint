# %%
import torch
import os
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline

os.environ["HF_TOKEN"] = "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"

# 모델과 토크나이절르 로드합니다.
model = AutoModelForCausalLM.from_pretrained(
    "microsoft/Phi-3-mini-4k-instruct",
    device_map="cuda",
    dtype="auto"
)
tokenizer = AutoTokenizer.from_pretrained("microsoft/Phi-3-mini-4k-instruct")

# 파이프라인을 만듭니다.
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    return_full_text=False,
    max_new_tokens=500,
    do_sample=False,
)
# Out:
# Loading weights: 100%|██████████| 195/195 [00:02<00:00, 65.21it/s]

# %%
# 프롬프트
messages = [
    {"role": "user", "content": "날씨와 관련된 재미있는 농담 생성해줘"}
]

# 출력을 생성합니다.
output = pipe(messages)
print(output[0]["generated_text"])
# Out:
# [transformers] The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# [transformers] Both `max_new_tokens` (=500) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer TokenizersBackend. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
# 날씨가 맑고 따뜻해서 날씨가 좋아요. 이런 날씨는 맛있는 저녁 식사를 위해 좋겠어요. 또한, 이렇게 맑은 날씨는 산책하는 데 좋은 날이에요. 눈이 높아도 맑아서 눈으로 놀러 가면 눈을 찢지 않게 되길 바래요. 그런데 날씨가 바빠서 집에 있어야 해요. 너무 날씨가 좋아서 집에 안 가면 눈이 높아서 눈을 찢지 않게 되길 바래요. 그러니까 날씨가 좋아서 집에 안 가면 눈을 찢지 않게 되지 않을까요? 너무 맑아서 눈이 높아서 눈을 찢지 않게 되지 않을까요? 눈이 높아서 눈을 찢지 않게 되지 않을까요? 눈이 높아서 눈을 찢지 않게 되지 않을까요?

# %%
import gc
import torch

gc.collect()
torch.cuda.empty_cache()

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
# 한국에서 개발된 카카오 모델을 로드한다.
#   - kakaocorp/kanana-2-3b-instruct
tokenizer = AutoTokenizer.from_pretrained("kakaocorp/kanana-2-3b-instruct")
model = AutoModelForCausalLM.from_pretrained("kakaocorp/kanana-2-3b-instruct", device_map="auto")
# Out:
# Loading weights: 100%|██████████| 355/355 [00:01<00:00, 209.62it/s]

# %%
# 파이프라인을 만듭니다.
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    return_full_text=False,
    max_new_tokens=500,
    do_sample=False,
)

# 프롬프트
messages = [
    {"role": "user", "content": "날씨와 관련된 재미있는 농담 생성해줘"}
]

# 출력을 생성합니다.
output = pipe(messages)
print(output[0]["generated_text"])
# Out:
# [transformers] Both `max_new_tokens` (=500) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 물론이죠! 날씨와 관련된 재미있는 농담 하나 만들어드릴게요.
#
# ---
#
# 비가 올 때마다 내 우산은 항상 내 옆에 있어.
# 그런데 오늘은 내 우산이 사라졌어.
# 그래서 나는 그냥 비를 맞으며 걸어가고 있어.
# (근데 왜 내 우산이 사라졌을까?
# 아마도… 바람이 너무 세게 불어서 날아간 것 같아!)
#
# ---
#
# 재밌게 보셨나요? 😄

# %%
# 프롬프트
messages = [
    {"role": "user", "content": "Create a funny joke about chickens."}
]

# 출력을 생성합니다.
output = pipe(messages)
print(output[0]["generated_text"])
# Out:
# [transformers] Both `max_new_tokens` (=500) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Why did the chicken join a band?
#
# Because it wanted to be a *rooster*! 🐔🎸

# %%
# 프롬프트
messages = [
    {"role": "user", "content": "날씨와 관련된 재미있는 농담 생성해줘"}
]

# %%
# 프롬프트 템플릿을 적용합니다.
prompt = pipe.tokenizer.apply_chat_template(messages, tokenize=False)
print(prompt)
# Out:
# <|im_start|>user
# 날씨와 관련된 재미있는 농담 생성해줘<|im_end|>

# %%
# 높은 temperature를 사용합니다.
output = pipe(messages, do_sample=True, temperature=1)
print(output[0]["generated_text"])
# Out:
# [transformers] Passing `generation_config` together with generation-related arguments=({'do_sample', 'temperature'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# [transformers] Both `max_new_tokens` (=500) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 물론이죠! 날씨와 관련된 재미있는 농담 하나 남겨드릴게요.
#
# ---
#
# 비가 내리면 왜 우산을 들까요?
# 그건 우산 탓이 아니라, 햇빛 탓이야! (The umbrella is not to blame—it’s the sun that makes us cover up.)
#
# ---
#
# 혹시 더 필요하시면 말씀해 주세요!

# %%
# 높은 top_p를 사용합니다.
output = pipe(messages, do_sample=True, top_p=50)
print(output[0]["generated_text"])
# Out:
# [transformers] Passing `generation_config` together with generation-related arguments=({'top_p', 'do_sample'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# [transformers] Both `max_new_tokens` (=500) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 물론이죠! 날씨와 관련된 재미있는 농담을 하나 만들어볼게요.
#
# ---
#
# 비가 억수같이 내리는데, 우산이 없어서 그냥 뛰어가던 사람이 하늘을 올려다보며 말했다.
# "하늘 좀 봐! 오늘은 완전 하늘 파티네!"
#
# ---
#
# 원하는 스타일이나 다른 농담도 원하시면 말씀해 주세요!

# %%
import gc
import torch

gc.collect()
torch.cuda.empty_cache()

# %%
import torch
import os
from transformers import AutoTokenizer, AutoModelForCausalLM


os.environ["HF_TOKEN"] = "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"

tokenizer = AutoTokenizer.from_pretrained("upstage/SOLAR-10.7B-v1.0")
model = AutoModelForCausalLM.from_pretrained("upstage/SOLAR-10.7B-v1.0", device_map="auto")
# Out:
# Fetching 5 files: 100%|██████████| 5/5 [03:11<00:00, 38.30s/it]
# Loading weights: 100%|██████████| 435/435 [00:06<00:00, 72.16it/s]
# Some parameters are on the meta device because they were offloaded to the cpu.

# %%
os.environ["HF_TOKEN"] = "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"

tokenizer = AutoTokenizer.from_pretrained("skt/A.X-4.0-Light")
model = AutoModelForCausalLM.from_pretrained("skt/A.X-4.0-Light", device_map="cuda")
# Out:
# Loading weights: 100%|██████████| 339/339 [00:13<00:00, 25.54it/s]

# %%
from transformers import pipeline

# 파이프라인을 만듭니다.
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    return_full_text=False,
    max_new_tokens=500,
    do_sample=False,
)

# %%
text = """지난 포스트에서는 현대 딥러닝 모델에서 널리 사용되는 기법인 '어텐션(Attention)'에 대해 살펴보았습니다. 어텐션은 신경망 기계 번역(NMT) 애플리케이션의 성능을 향상시키는 데 기여한 개념입니다. 이번 포스트에서는 어텐션을 활용하여 모델 학습 속도를 획기적으로 높인 모델인 '트랜스포머(Transformer)'를 다뤄보겠습니다. 트랜스포머는 특정 작업에서 구글 신경망 기계 번역(GNMT) 모델보다 뛰어난 성능을 보여줍니다. 하지만 트랜스포머의 가장 큰 장점은 병렬 처리에 최적화되어 있다는 점입니다. 실제로 구글 클라우드는 자사의 Cloud TPU 서비스를 활용하기 위한 참조 모델로 트랜스포머를 권장하고 있습니다. 그럼 이제 이 모델을 구성 요소별로 나누어 그 작동 원리를 자세히 살펴보겠습니다.
트랜스포머는 'Attention Is All You Need'라는 논문을 통해 처음 제안되었습니다. 이 모델의 TensorFlow 구현체는 Tensor2Tensor 패키지의 일부로 제공됩니다. 또한 하버드 대학교의 NLP 연구 그룹은 해당 논문의 내용을 설명하고 PyTorch로 구현한 가이드를 제작하기도 했습니다. 이번 포스트에서는 전문 지식이 없는 분들도 쉽게 이해할 수 있도록, 복잡한 내용을 다소 단순화하여 핵심 개념을 하나씩 소개해 드리겠습니다.
먼저 이 모델을 하나의 '블랙박스(black box)'로 간주하고 시작해 봅시다. 기계 번역 애플리케이션의 관점에서 보면, 이 모델은 특정 언어로 된 문장을 입력받아 다른 언어로 번역된 문장을 출력하는 역할을 합니다.
이제 그 내부를 들여다보면 인코딩(encoding) 구성 요소와 디코딩(decoding) 구성 요소, 그리고 이들을 연결하는 구조로 이루어져 있음을 확인할 수 있습니다.
인코딩 구성 요소는 인코더를 여러 층으로 쌓은 형태입니다(논문에서는 6개를 쌓았지만, 6이라는 숫자에 특별한 의미가 있는 것은 아니며 다른 구성을 시도해 볼 수도 있습니다). 디코딩 구성 요소 또한 동일한 개수의 디코더를 쌓은 형태입니다.
인코더들은 모두 구조가 동일하지만(가중치는 공유하지 않습니다), 각각 두 개의 하위 계층(sub-layer)으로 구성됩니다.
인코더의 입력값은 먼저 셀프 어텐션(self-attention) 계층을 통과합니다. 이 계층은 인코더가 특정 단어를 인코딩할 때 입력 문장 내의 다른 단어들도 함께 고려할 수 있도록 돕는 역할을 합니다. 셀프 어텐션에 대해서는 이 글의 뒷부분에서 더 자세히 살펴보겠습니다.
셀프 어텐션 계층의 출력값은 피드 포워드 신경망(feed-forward neural network)으로 전달됩니다. 이때 동일한 피드 포워드 신경망이 각 위치(position)에 독립적으로 적용됩니다.
디코더에도 해당 층들이 포함되어 있지만, 그 사이에는 디코더가 입력 문장의 관련 부분에 집중할 수 있도록 돕는 어텐션(attention) 층이 존재합니다(이는 seq2seq 모델의 어텐션 메커니즘과 유사합니다).
이제 모델의 주요 구성 요소를 살펴보았으니, 학습된 모델이 입력을 출력으로 변환하는 과정에서 다양한 벡터와 텐서가 이들 구성 요소 사이를 어떻게 이동하는지 알아보겠습니다.
일반적인 NLP(자연어 처리) 응용 분야에서 흔히 그렇듯이, 먼저 임베딩 알고리즘을 사용하여 각 입력 단어를 벡터로 변환하는 것부터 시작합니다.
각 단어는 크기가 512인 벡터로 임베딩됩니다. 이 벡터들은 간단한 상자 모양으로 표현하겠습니다.
임베딩(embedding) 과정은 최하단 인코더에서만 수행됩니다. 모든 인코더가 공유하는 공통적인 특징은 각 인코더가 크기 512인 벡터들의 리스트를 입력으로 받는다는 점입니다. 최하단 인코더의 경우 이 입력은 단어 임베딩이 되지만, 다른 인코더들의 경우 바로 아래에 위치한 인코더의 출력이 입력이 됩니다. 이 리스트의 크기는 우리가 설정할 수 있는 하이퍼파라미터인데, 기본적으로는 학습 데이터셋에서 가장 긴 문장의 길이에 맞춰지게 됩니다.
입력 시퀀스의 단어들이 임베딩된 후, 각 단어는 인코더의 두 계층(layer)을 차례로 통과하게 됩니다.
여기서 우리는 트랜스포머(Transformer)의 핵심적인 특징 중 하나를 확인할 수 있는데, 바로 각 위치에 있는 단어가 인코더 내에서 자신만의 경로를 따라 이동한다는 점입니다. 물론 '셀프 어텐션(self-attention)' 계층에서는 이러한 경로들 간에 상호 의존성이 존재합니다. 하지만 '피드 포워드(feed-forward)' 계층에는 그러한 의존성이 없기 때문에, 피드 포워드 계층을 통과할 때는 여러 경로가 병렬로 처리될 수 있습니다.
다음으로, 예시를 더 짧은 문장으로 바꾸어 인코더의 각 하위 계층(sub-layer)에서 어떤 일이 일어나는지 살펴보겠습니다.
이제 인코딩을 시작해 봅시다!
앞서 언급했듯이, 인코더는 벡터 리스트를 입력으로 받습니다. 인코더는 이 리스트를 '셀프 어텐션' 계층과 '피드 포워드 신경망'에 차례로 통과시켜 처리한 뒤, 그 결과를 상단에 있는 다음 인코더로 전달합니다.
"""

# %%
# 프롬프트 구성 요소
persona = "너는 거대 언어 모델(LLM) 분야의 전문가입니다. 복잡한 논문을 이해하기 쉬운 요약으로 풀어내는 데 탁월한 능력을 갖추고 있습니다.\n"
instruction = "제공된 논문의 주요 결과를 요약하십시오..\n"
context = "요약문은 연구자들이 논문의 핵심 정보를 신속하게 파악하는 데 도움이 되는 가장 중요한 사항들을 포함해야 합니다..\n"
data_format = "해당 방법을 개괄하는 요약 내용을 글머리 기호로 작성하십시오. 이어서 주요 결과를 요약한 간결한 단락을 제시하십시오.\n"
audience = "이 요약은 대규모 언어 모델(LLM)의 최신 동향을 빠르게 파악해야 하는 바쁜 연구자들을 위해 작성되었습니다..\n"
tone = "어조는 전문적이고 명확해야 합니다.\n"
text = "요약할 텍스트"  # Replace with your own text to summarize
data = f"요약할 텍스트: {text}"

# 전체 프롬프트 - 요소를 삭제하거나 추가하여 생성된 출력에 미치는 영향을 관찰하세요.
query = persona + instruction + context + data_format + audience + tone + data

messages = [
    {"role": "user", "content": query}
]
print(tokenizer.apply_chat_template(messages, tokenize=False))
# Out:
# <|im_start|><|user|>너는 거대 언어 모델(LLM) 분야의 전문가입니다. 복잡한 논문을 이해하기 쉬운 요약으로 풀어내는 데 탁월한 능력을 갖추고 있습니다.
# 제공된 논문의 주요 결과를 요약하십시오..
# 요약문은 연구자들이 논문의 핵심 정보를 신속하게 파악하는 데 도움이 되는 가장 중요한 사항들을 포함해야 합니다..
# 해당 방법을 개괄하는 요약 내용을 글머리 기호로 작성하십시오. 이어서 주요 결과를 요약한 간결한 단락을 제시하십시오.
# 이 요약은 대규모 언어 모델(LLM)의 최신 동향을 빠르게 파악해야 하는 바쁜 연구자들을 위해 작성되었습니다..
# 어조는 전문적이고 명확해야 합니다.
# 요약할 텍스트: 요약할 텍스트<|im_end|>

# %%
inputs = tokenizer(query, return_tensors="pt").to("cuda")

outputs = model.generate(**inputs, max_new_tokens=1000)
print(tokenizer.decode(outputs[0], skip_special_tokens=True))

# %%
# 출력을 생성합니다.
outputs = pipe(messages)
print(outputs[0]["generated_text"])
# Out:
# [transformers] Both `max_new_tokens` (=500) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer Qwen2Tokenizer. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
# ### 요약: 대규모 언어 모델(LLM)의 최신 동향
#
# - **LLM의 발전 방향**
#   - 최근 LLM은 더 큰 모델 크기와 더 많은 파라미터를 통해 성능 향상.
#   - 효율적인 학습 및 추론 방법(예: 지식 증류, 양자화)이 주목받고 있음.
#   - 멀티모달 처리 능력(텍스트, 이미지, 음성 등)이 강화되고 있음.
#
# - **주요 결과 요약**
#   최신 대규모 언어 모델(LLM) 연구는 모델 크기 확대와 효율적인 학습 기법에 중점을 두고 있으며, 멀티모달 처리 능력이 크게 향상되었습니다. 또한, 지식 증류 및 양자화 같은 기술을 통해 모델의 경량화와 추론 속도 개선이 이루어지고 있습니다. 이러한 발전은 LLM의 실용성을 높이고 다양한 응용 분야에서의 활용 가능성을 확장하고 있습니다.

# %%
# 전체 프롬프트 - 요소를 삭제하거나 추가하여 생성된 출력에 미치는 영향을 관찰하세요.
query = instruction + data_format + audience + data

messages = [
    {"role": "user", "content": query}
]
print(tokenizer.apply_chat_template(messages, tokenize=False))
# Out:
# <|im_start|><|user|>제공된 논문의 주요 결과를 요약하십시오..
# 해당 방법을 개괄하는 요약 내용을 글머리 기호로 작성하십시오. 이어서 주요 결과를 요약한 간결한 단락을 제시하십시오.
# 이 요약은 대규모 언어 모델(LLM)의 최신 동향을 빠르게 파악해야 하는 바쁜 연구자들을 위해 작성되었습니다..
# 요약할 텍스트: 요약할 텍스트<|im_end|>

# %%
# 출력을 생성합니다.
outputs = pipe(messages)
print(outputs[0]["generated_text"])
# Out:
# [transformers] Both `max_new_tokens` (=500) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# ### 주요 결과 요약
#
# - **LLM의 성능 향상**: 최신 대규모 언어 모델(LLM)은 더 많은 파라미터를 통해 이전 모델들보다 더 높은 정확도를 달성함.
# - **효율적인 학습 방법**: 새로운 학습 기법인 '지식 증류'와 '혼합 정밀도 훈련'이 LLM의 학습 속도와 효율성을 크게 개선함.
# - **다양한 응용 분야**: LLM은 자연어 처리(NLP)뿐만 아니라 이미지 인식, 코드 생성 등 다양한 분야에 적용되고 있음.
# - **윤리적 고려**: LLM의 확산이 개인정보 보호 및 편향성 문제를 야기할 수 있어, 윤리적 가이드라인과 규제 필요성이 강조됨.
# - **모델 경량화**: 경량화된 모델 아키텍처가 개발되어, 리소스가 제한된 환경에서도 LLM의 활용이 가능해지고 있음.
#
# ### 주요 결과 요약
#
# 최신 대규모 언어 모델(LLM)은 파라미터 수 증가와 효율적인 학습 방법 도입으로 성능이 크게 향상되었으며, 다양한 분야에 응용되고 있다. 그러나 개인정보 보호 및 윤리적 문제에 대한 고려가 필요하며, 경량화된 모델도 개발되어 리소스 제한 환경에서도 활용 가능성이 높아지고 있다.

# %%
query = persona + instruction + context + data_format + audience  + data

messages = [
    {"role": "user", "content": query}
]
print(tokenizer.apply_chat_template(messages, tokenize=False))
# Out:
# <|im_start|><|user|>너는 거대 언어 모델(LLM) 분야의 전문가입니다. 복잡한 논문을 이해하기 쉬운 요약으로 풀어내는 데 탁월한 능력을 갖추고 있습니다.
# 제공된 논문의 주요 결과를 요약하십시오..
# 요약문은 연구자들이 논문의 핵심 정보를 신속하게 파악하는 데 도움이 되는 가장 중요한 사항들을 포함해야 합니다..
# 해당 방법을 개괄하는 요약 내용을 글머리 기호로 작성하십시오. 이어서 주요 결과를 요약한 간결한 단락을 제시하십시오.
# 이 요약은 대규모 언어 모델(LLM)의 최신 동향을 빠르게 파악해야 하는 바쁜 연구자들을 위해 작성되었습니다..
# 요약할 텍스트: 요약할 텍스트<|im_end|>

# %%
# 출력을 생성합니다.
outputs = pipe(messages)
print(outputs[0]["generated_text"])
# Out:
# [transformers] Both `max_new_tokens` (=500) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# ### 요약: 대규모 언어 모델(LLM)의 최신 동향
#
# - **LLM의 발전 방향**
#   - 최근 LLM은 더 큰 모델 크기와 더 많은 파라미터를 통해 성능 향상.
#   - 효율적인 학습 및 추론 방법(예: 지식 증류, 양자화)이 주목받고 있음.
#   - 멀티모달 처리 능력(텍스트, 이미지, 음성 등)이 강화되고 있음.
#
# - **주요 결과 요약**
#   최신 대규모 언어 모델(LLM) 연구는 모델 크기를 확장하고, 학습 효율성을 높이며, 멀티모달 기능을 통합하는 방향으로 진행되고 있다. 특히, 지식 증류 및 양자화 기법을 통해 연산 비용을 절감하면서도 성능을 유지하거나 향상시키는 방법이 주목받고 있으며, 텍스트뿐만 아니라 이미지, 음성 등 다양한 형태의 데이터를 처리할 수 있는 멀티모달 LLM의 발전이 두드러진다. 이러한 경향은 LLM의 실용성을 높이고, 다양한 산업 분야에서의 적용 가능성을 확장하는 데 기여하고 있다.

# %%
# 문장에 가상의 단어가 포함된 예시를 사용합니다.
one_shot_prompt = [
    {
        "role": "user",
        "content": "'Gigamuru'는 일본 악기의 일종입니다. 'Gigamuru'라는 단어를 사용한 문장의 예는 다음과 같습니다.:"
    },
    {
        "role": "assistant",
        "content": "삼촌이 선물로 주신 기가무루(Gigamuru)가 하나 있어요. 집에서 연주하는 걸 정말 좋아해요.."
    },
    {
        "role": "user",
        "content": "Screeg'는 무언가를 향해 칼을 휘두른다는 뜻입니다. 'Screeg'라는 단어를 사용한 문장의 예는 다음과 같습니다:"
    }
]
print(tokenizer.apply_chat_template(one_shot_prompt, tokenize=False))
# Out:
# <|im_start|><|user|>'Gigamuru'는 일본 악기의 일종입니다. 'Gigamuru'라는 단어를 사용한 문장의 예는 다음과 같습니다.:<|im_end|><|im_start|><|assistant|>삼촌이 선물로 주신 기가무루(Gigamuru)가 하나 있어요. 집에서 연주하는 걸 정말 좋아해요..<|im_end|><|im_start|><|user|>Screeg'는 무언가를 향해 칼을 휘두른다는 뜻입니다. 'Screeg'라는 단어를 사용한 문장의 예는 다음과 같습니다:<|im_end|>

# %%
# 출력을 생성합니다.
outputs = pipe(one_shot_prompt)
print(outputs[0]["generated_text"])
# Out:
# [transformers] Both `max_new_tokens` (=500) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 전투 중에 적군을 향해 칼을 휘두르며 screeg를 시도했지만, 방어에 막혀 실패했습니다.

# %%
# 제품 이름과 슬로건을 만듭니다.
product_prompt = [
    {"role": "user", "content": "LLM을 활용하는 챗봇의 이름과 슬로건을 제시해라. 제시할 이름과 슬로건의 개수는 각각 1개이다. 양식은 '이름: '\n, '슬로건: '\n으로 해라. "}
]
outputs = pipe(product_prompt)
product_description = outputs[0]["generated_text"]
print(product_description)
# Out:
# [transformers] Both `max_new_tokens` (=500) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 이름: AI companion
# 슬로건: "당신의 생각을 현실로, 함께하는 AI 친구"

# %%
# 제품 이름과 슬로건을 바탕으로 홍보 문구를 생성합니다.
sales_prompt = [
    {"role": "user", "content": f"다음 제품을 위한 아주 짧은 세일즈 포인트를 ​​작성해 주세요.: '{product_description}'"}
]
outputs = pipe(sales_prompt)
sales_pitch = outputs[0]["generated_text"]
print(sales_pitch)
# Out:
# [transformers] Both `max_new_tokens` (=500) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# **AI Companion**
#
# * **슬로건:** "당신의 생각을 현실로, 함께하는 AI 친구"
# * **세일즈 포인트:**
#   - **개인화된 지원:** 당신의 취향과 필요에 맞춘 맞춤형 조언 제공
#   - **24/7 접근성:** 언제 어디서나 대화하며 도움을 받을 수 있는 AI 친구
#   - **효율성 향상:** 일상 업무 자동화 및 시간 절약
#   - **감정적 연결:** 자연스러운 대화로 정서적 지지 제공
#   - **지속적인 학습:** 사용자와의 상호작용을 통해 점점 더 똑똑해지는 AI

# %%
# 추론없이 답변하기
standard_prompt = [
    {"role": "user", "content": "로저는 테니스 공 5개를 가지고 있습니다. 그는 테니스 공 2통을 더 삽니다. 각 통에는 테니스 공 3개가 들어 있습니다. 이제 로저가 가진 테니스 공은 모두 몇 개일까요?"},
    {"role": "assistant", "content": "11"},
    {"role": "user", "content": "구내식당에 사과가 25개 있었습니다. 점심 식사를 만드는 데 20개를 사용하고 6개를 더 샀다면, 사과가 몇 개 있습니까?"}
]

# 출력을 생성합니다.
outputs = pipe(standard_prompt)
print(outputs[0]["generated_text"])
# Out:
# [transformers] Both `max_new_tokens` (=500) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 구내식당에 처음에 사과가 25개 있었습니다. 점심 식사를 위해 20개를 사용했으므로, 남은 사과는 25 - 20 = 5개입니다. 여기에 6개를 더 샀으므로, 최종적으로 사과 개수는 5 + 6 = 11개입니다. 따라서, 구내식당에는 총 11개의 사과가 있습니다.

# %%
# CoT로 대답하기
cot_prompt = [
    {"role": "user", "content": "로저는 테니스 공 5개를 가지고 있습니다. 그는 테니스 공 2통을 더 삽니다. 각 통에는 테니스 공 3개가 들어 있습니다. 이제 로저가 가진 테니스 공은 모두 몇 개일까요?"},
    {"role": "assistant", "content": "로저는 처음에 공 5개를 가지고 있었습니다. 테니스 공 3개씩 들어 있는 캔 2개는 테니스 공 6개입니다. 5 + 6 = 11이므로, 정답은 11입니다."},
    {"role": "user", "content": "구내식당에 사과가 23개 있었습니다. 점심 식사를 만드는 데 20개를 사용하고 6개를 더 샀다면, 사과가 몇 개 있습니까?"}
]

# 출력을 생성합니다.
outputs = pipe(cot_prompt)
print(outputs[0]["generated_text"])
# Out:
# [transformers] Both `max_new_tokens` (=500) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 구내식당에는 처음에 사과가 23개 있었습니다. 점심 식사를 위해 20개를 사용했으므로, 남은 사과는 23 - 20 = 3개입니다. 여기에 6개를 더 샀으므로, 최종적으로 사과 개수는 3 + 6 = 9개입니다. 따라서 구내식당에는 사과가 9개 있습니다.

# %%
# 제로-샷 ToT
zeroshot_tot_prompt = [
    {"role": "user", "content": "세 명의 서로 다른 전문가가 이 질문에 답한다고 가정해 봅시다. 모든 전문가는 자신의 사고 과정을 한 단계씩 적은 뒤 이를 그룹과 공유합니다. 그런 다음 모든 전문가가 다음 단계로 넘어가는 식으로 진행합니다. 만약 어느 단계에서든 자신의 생각이 틀렸음을 깨닫는 전문가가 있다면 그 전문가는 논의에서 빠지게 됩니다. 질문은 다음과 같습니다. '구내식당에 사과가 23개 있었습니다. 점심 식사 준비에 20개를 사용하고 6개를 더 구입했다면, 현재 사과는 몇 개가 있을까요?' 논의 결과를 반드시 다루어 주십시오.."}
]

# %%
# 출력을 생성합니다.
outputs = pipe(zeroshot_tot_prompt)
print(outputs[0]["generated_text"])
# Out:
# [transformers] Both `max_new_tokens` (=500) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# ### 전문가 1의 사고 과정
#
# 1. **초기 사과 수**: 구내식당에 처음에 사과가 23개 있었습니다.
# 2. **사용된 사과 수**: 점심 식사 준비에 20개를 사용했습니다.
#    - 계산: 23 - 20 = 3
#    - 현재 남아 있는 사과는 3개입니다.
# 3. **추가된 사과 수**: 6개를 더 구입했습니다.
#    - 계산: 3 + 6 = 9
#    - 최종적으로 현재 사과는 9개입니다.
#
# ### 전문가 2의 사고 과정
#
# 1. **초기 사과 수**: 23개.
# 2. **사과 사용**: 20개를 사용했습니다.
#    - 계산: 23 - 20 = 3
#    - 사용 후 3개가 남습니다.
# 3. **사과 추가**: 6개를 더 샀습니다.
#    - 계산: 3 + 6 = 9
#    - 따라서 현재 사과는 9개입니다.
#
# ### 전문가 3의 사고 과정
#
# 1. **초기 상태**: 구내식당에 사과가 23개.
# 2. **사과 소비**: 20개를 사용했습니다.
#    - 계산: 23 - 20 = 3
#    - 3개가 남았습니다.
# 3. **사과 보충**: 6개를 추가했습니다.
#    - 계산: 3 + 6 = 9
#    - 현재 구내식당에는 9개의 사과가 있습니다.
#
# ### 그룹 논의 결과
#
# - **모든 전문가가 동일한 결론에 도달**: 각 전문가가 독립적으로 계산한 결과, 현재 구내식당에 있는 사과의 수는 9개로 일치합니다.
# - **오류 검토**: 모든 전문가가 자신의 계산 과정을 공유했고, 계산 과정에서 오류가 없음을 확인했습니다. 따라서 어느 누구도 논의에서 빠지지 않았습니다.
# - **결론**: 최종적으로, 구내식당에 현재 있는 사과의 수는 9개입니다.
#
# **최종 답변**: 현재 구내식당에 있는 사과의 수는 9개입니다.

# %%
# 제로-샷 ToT
zeroshot_tot_prompt = [
    {"role": "user", "content": "Imagine three different experts are answering this question. All experts will write down 1 step of their thinking, then share it with the group. Then all experts will go on to the next step, etc. If any expert realises they're wrong at any point then they leave. The question is 'The cafeteria had 23 apples. If they used 20 to make lunch and bought 6 more, how many apples do they have?' Make sure to discuss the results."}
]
# 출력을 생성합니다.
outputs = pipe(zeroshot_tot_prompt)
print(outputs[0]["generated_text"])
# Out:
# [transformers] Both `max_new_tokens` (=500) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# **Expert 1:**
# *Step 1:* Start with the initial number of apples, which is 23.
# *Step 2:* Subtract the 20 apples used for lunch. 23 - 20 = 3 apples remain.
# *Step 3:* Add the 6 apples bought later. 3 + 6 = 9 apples.
# *Conclusion:* The cafeteria has 9 apples.
#
# **Expert 2:**
# *Step 1:* Begin with the initial count of apples, 23.
# *Step 2:* Deduct the 20 apples used for lunch. This leaves 3 apples.
# *Step 3:* Add the 6 new apples purchased. The total becomes 9 apples.
# *Conclusion:* The cafeteria ends up with 9 apples.
#
# **Expert 3:**
# *Step 1:* The cafeteria starts with 23 apples.
# *Step 2:* After using 20 apples, the count drops to 3.
# *Step 3:* The purchase of 6 more apples increases the total to 9.
# *Conclusion:* The final number of apples is 9.
#
# **Discussion:**
# All three experts reached the same conclusion: the cafeteria has 9 apples after using 20 and buying 6 more. The process of deducting and adding apples was consistent across all experts, and no one realized they were wrong at any point. The steps were straightforward arithmetic operations, and the final answer is unanimous. This demonstrates that the problem was solved correctly and efficiently by all experts.

# %%
# 제로-샷 학습: 예시 없음
zeroshot_prompt = [
    {"role": "user", "content": "JSON 형식으로 RPG 게임 캐릭터 프로필을 작성하세요."}
]

# 출력을 생성합니다.
outputs = pipe(zeroshot_prompt)
print(outputs[0]["generated_text"])
# Out:
# [transformers] You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# [transformers] Both `max_new_tokens` (=500) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# ```json
# {
#   "character": {
#     "name": "엘라 윈드브레이커",
#     "class": "소서리스",
#     "level": 7,
#     "attributes": {
#       "strength": 4,
#       "agility": 8,
#       "intelligence": 10,
#       "vitality": 6
#     },
#     "stats": {
#       "hp": 120,
#       "mana": 180,
#       "attack": 25,
#       "defense": 15,
#       "crit_chance": 10,
#       "move_speed": 3.5
#     },
#     "skills": [
#       {
#         "name": "불꽃의 주문",
#         "type": "공격",
#         "damage": 40,
#         "cooldown": 6
#       },
#       {
#         "name": "어둠의 보호막",
#         "type": "방어",
#         "duration": 8,
#         "mana_cost": 60
#       },
#       {
#         "name": "시간 왜곡",
#         "type": "보조",
#         "effect": "이동 속도 20% 증가",
#         "duration": 5,
#         "cooldown": 12
#       }
#     ],
#     "equipment": {
#       "weapon": "불꽃의 지팡이",
#       "armor": "어둠의 로브",
#       "accessory": "운명의 반지"
#     },
#     "backstory": "엘라 윈드브레이커는 바람의 고원에서 태어난 소서리스로, 자연의 힘을 조종하는 능력을 지니고 있다. 그녀는 어둠의 세력에 맞서 세상을 지키기 위해 모험을 떠났다.",
#     "favorites": {
#       "food": "허브 스튜",
#       "drink": "마법의 엘릭서",
#       "color": "푸른색"
#     }
#   }
# }
# ```

# %%
# 원-샷 학습: 출력 구조에 대한 예시를 제공합니다.
one_shot_template = """한 개의 RPG 게임용 캐릭터 프로필을 간단히 작성해 주세요. 반드시 아래의 형식만 사용해야 한다.:

{
  "description": "간략한 설명",
  "name": "캐릭터의 이름",
  "armor": "사용중인 갑옷 정보",
  "weapon": "사용중인 무기 정보"
}
"""
one_shot_prompt = [
    {"role": "user", "content": one_shot_template}
]

# 출력을 생성합니다.
outputs = pipe(one_shot_prompt)
print(outputs[0]["generated_text"])
# Out:
# [transformers] Both `max_new_tokens` (=500) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# ```json
# {
#   "description": "고대의 마법을 다루는 전사. 전투와 마법 모두에 능하며, 빛의 힘을 수호한다.",
#   "name": "엘라린 더 라이트브링어",
#   "armor": "은빛 비늘 갑옷 - 방어력 +5, 민첩성 +2",
#   "weapon": "빛의 검 - 공격력 +4, 마법 저항 +10%"
# }
# ```
